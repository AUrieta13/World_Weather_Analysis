# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        Description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, "Current Description": Description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | alamogordo
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | hambantota
# Processing Record 7 of Set 1 | egvekinot
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 1 | storm lake
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | grabs
# Processing Record 14 of Set 1 | takoradi
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | aguimes
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | sao filipe
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | pedasi
# Processing Record 21 of Set 1 | klaksvik
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | krasnoselkup
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | chengde
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | chicama
# Processing Record 36 of Set 1 | korla
# Processing Record 37 of Set 1 | apaseo el alto
# Processing Record 38 of Set 1 | novoilinsk
# Processing Record 39 of Set 1 | meulaboh
# Processing Record 40 of Set 1 | port blair
# Processing Record 41 of Set 1 | airai
# Processing Record 42 of Set 1 | delijan
# Processing Record 43 of Set 1 | zwedru
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | the valley
# Processing Record 46 of Set 1 | lorengau
# Processing Record 47 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 1 | imbituba
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | aklavik
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | tawzar
# City not found. Skipping...
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | maniitsoq
# Processing Record 6 of Set 2 | gilgit
# Processing Record 7 of Set 2 | tromso
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | ormara
# Processing Record 10 of Set 2 | lokoja
# Processing Record 11 of Set 2 | brazzaville
# Processing Record 12 of Set 2 | chikwawa
# Processing Record 13 of Set 2 | manbij
# Processing Record 14 of Set 2 | williamsport
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | kavieng
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | tessalit
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | miranda
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | adzope
# Processing Record 25 of Set 2 | carauari
# Processing Record 26 of Set 2 | lianzhou
# Processing Record 27 of Set 2 | ferrandina
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | babol
# Processing Record 30 of Set 2 | hami
# Processing Record 31 of Set 2 | changying
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | bambous virieux
# Processing Record 34 of Set 2 | saint-francois
# Processing Record 35 of Set 2 | pervomayskoye
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | burgos
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | ayagoz
# Processing Record 41 of Set 2 | nemuro
# Processing Record 42 of Set 2 | homer
# Processing Record 43 of Set 2 | prince rupert
# Processing Record 44 of Set 2 | springbok
# Processing Record 45 of Set 2 | genhe
# Processing Record 46 of Set 2 | fundata
# Processing Record 47 of Set 2 | aitape
# Processing Record 48 of Set 2 | vanavara
# Processing Record 49 of Set 2 | ilulissat
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | sistranda
# Processing Record 2 of Set 3 | port lincoln
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | dalaba
# Processing Record 5 of Set 3 | kuantan
# Processing Record 6 of Set 3 | marsabit
# Processing Record 7 of Set 3 | praia da vitoria
# Processing Record 8 of Set 3 | hofn
# Processing Record 9 of Set 3 | wladyslawowo
# Processing Record 10 of Set 3 | mizdah
# Processing Record 11 of Set 3 | tuatapere
# Processing Record 12 of Set 3 | opelousas
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | sambava
# Processing Record 16 of Set 3 | soldotna
# Processing Record 17 of Set 3 | murdochville
# Processing Record 18 of Set 3 | kruisfontein
# Processing Record 19 of Set 3 | tubuala
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | tabarqah
# City not found. Skipping...
# Processing Record 22 of Set 3 | merauke
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | avera
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | lompoc
# Processing Record 27 of Set 3 | plouzane
# Processing Record 28 of Set 3 | manggar
# Processing Record 29 of Set 3 | qena
# Processing Record 30 of Set 3 | karpathos
# Processing Record 31 of Set 3 | atyrau
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | price
# Processing Record 36 of Set 3 | nome
# Processing Record 37 of Set 3 | matlock
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | flinders
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 3 | kaura namoda
# Processing Record 43 of Set 3 | bethel
# Processing Record 44 of Set 3 | vardo
# Processing Record 45 of Set 3 | carutapera
# Processing Record 46 of Set 3 | port hedland
# Processing Record 47 of Set 3 | kirkwood
# Processing Record 48 of Set 3 | tambul
# City not found. Skipping...
# Processing Record 49 of Set 3 | vaini
# Processing Record 50 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 4 | kalmunai
# Processing Record 2 of Set 4 | januaria
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | finschhafen
# Processing Record 6 of Set 4 | kijang
# Processing Record 7 of Set 4 | namatanai
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | touros
# Processing Record 10 of Set 4 | kindu
# Processing Record 11 of Set 4 | gat
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | rawson
# Processing Record 14 of Set 4 | nikolskoye
# Processing Record 15 of Set 4 | torbay
# Processing Record 16 of Set 4 | zhigansk
# Processing Record 17 of Set 4 | faanui
# Processing Record 18 of Set 4 | dhidhdhoo
# Processing Record 19 of Set 4 | obihiro
# Processing Record 20 of Set 4 | boo
# Processing Record 21 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 4 | solnechnyy
# Processing Record 23 of Set 4 | bairiki
# Processing Record 24 of Set 4 | agnibilekrou
# Processing Record 25 of Set 4 | lermontovka
# Processing Record 26 of Set 4 | port elizabeth
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | komsomolskiy
# Processing Record 29 of Set 4 | dunedin
# Processing Record 30 of Set 4 | georgetown
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | balabac
# Processing Record 33 of Set 4 | weligama
# Processing Record 34 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 4 | charleston
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | beyneu
# Processing Record 38 of Set 4 | great bend
# Processing Record 39 of Set 4 | coolum beach
# Processing Record 40 of Set 4 | urengoy
# Processing Record 41 of Set 4 | broken hill
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | hornepayne
# Processing Record 44 of Set 4 | sibolga
# Processing Record 45 of Set 4 | lata
# Processing Record 46 of Set 4 | fortuna
# Processing Record 47 of Set 4 | dudinka
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | toamua
# City not found. Skipping...
# Processing Record 50 of Set 4 | salonta
# Processing Record 1 of Set 5 | aporawan
# City not found. Skipping...
# Processing Record 2 of Set 5 | lakhimpur
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | newport
# Processing Record 5 of Set 5 | noyabrsk
# Processing Record 6 of Set 5 | gohad
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | hurghada
# Processing Record 10 of Set 5 | bonavista
# Processing Record 11 of Set 5 | porvoo
# Processing Record 12 of Set 5 | belovo
# Processing Record 13 of Set 5 | lebu
# Processing Record 14 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 5 | narsaq
# Processing Record 16 of Set 5 | alugan
# Processing Record 17 of Set 5 | chuy
# Processing Record 18 of Set 5 | pavlovsk
# Processing Record 19 of Set 5 | llaillay
# Processing Record 20 of Set 5 | ixtapa
# Processing Record 21 of Set 5 | hamilton
# Processing Record 22 of Set 5 | bluff
# Processing Record 23 of Set 5 | yangambi
# Processing Record 24 of Set 5 | bilibino
# Processing Record 25 of Set 5 | jinan
# Processing Record 26 of Set 5 | asfi
# Processing Record 27 of Set 5 | kayerkan
# Processing Record 28 of Set 5 | monchegorsk
# Processing Record 29 of Set 5 | ocos
# Processing Record 30 of Set 5 | geraldton
# Processing Record 31 of Set 5 | guerrero negro
# Processing Record 32 of Set 5 | san antonio
# Processing Record 33 of Set 5 | abapo
# Processing Record 34 of Set 5 | zhigalovo
# Processing Record 35 of Set 5 | khartoum
# Processing Record 36 of Set 5 | necochea
# Processing Record 37 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 38 of Set 5 | noumea
# Processing Record 39 of Set 5 | honiara
# Processing Record 40 of Set 5 | srednekolymsk
# Processing Record 41 of Set 5 | chingirlau
# Processing Record 42 of Set 5 | bondo
# Processing Record 43 of Set 5 | reitz
# Processing Record 44 of Set 5 | brae
# Processing Record 45 of Set 5 | lufilufi
# Processing Record 46 of Set 5 | sur
# Processing Record 47 of Set 5 | hanyang
# Processing Record 48 of Set 5 | molo
# Processing Record 49 of Set 5 | buritizeiro
# Processing Record 50 of Set 5 | santa barbara
# Processing Record 1 of Set 6 | nanortalik
# Processing Record 2 of Set 6 | sao francisco
# Processing Record 3 of Set 6 | tarpon springs
# Processing Record 4 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 6 | comodoro rivadavia
# Processing Record 6 of Set 6 | japura
# Processing Record 7 of Set 6 | najran
# Processing Record 8 of Set 6 | lasa
# Processing Record 9 of Set 6 | darnah
# Processing Record 10 of Set 6 | vangaindrano
# Processing Record 11 of Set 6 | cabo san lucas
# Processing Record 12 of Set 6 | rio gallegos
# Processing Record 13 of Set 6 | sisimiut
# Processing Record 14 of Set 6 | qaqortoq
# Processing Record 15 of Set 6 | vidim
# Processing Record 16 of Set 6 | tiksi
# Processing Record 17 of Set 6 | murwillumbah
# Processing Record 18 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 6 | pangnirtung
# Processing Record 20 of Set 6 | krasnokholm
# Processing Record 21 of Set 6 | sivaki
# Processing Record 22 of Set 6 | cherskiy
# Processing Record 23 of Set 6 | hasaki
# Processing Record 24 of Set 6 | vila
# Processing Record 25 of Set 6 | panguna
# Processing Record 26 of Set 6 | itatiaia
# Processing Record 27 of Set 6 | samarai
# Processing Record 28 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 6 | chernyshevskiy
# Processing Record 30 of Set 6 | druzhnaya gorka
# Processing Record 31 of Set 6 | westerland
# Processing Record 32 of Set 6 | yabrud
# Processing Record 33 of Set 6 | san patricio
# Processing Record 34 of Set 6 | kaka
# Processing Record 35 of Set 6 | college
# Processing Record 36 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 6 | portland
# Processing Record 38 of Set 6 | talnakh
# Processing Record 39 of Set 6 | uzunkopru
# City not found. Skipping...
# Processing Record 40 of Set 6 | novaya mayna
# Processing Record 41 of Set 6 | goderich
# Processing Record 42 of Set 6 | thanyaburi
# Processing Record 43 of Set 6 | jibuti
# Processing Record 44 of Set 6 | doka
# Processing Record 45 of Set 6 | longyan
# Processing Record 46 of Set 6 | roswell
# Processing Record 47 of Set 6 | tautira
# Processing Record 48 of Set 6 | dalby
# Processing Record 49 of Set 6 | nhulunbuy
# Processing Record 50 of Set 6 | yumen
# Processing Record 1 of Set 7 | burica
# City not found. Skipping...
# Processing Record 2 of Set 7 | namtsy
# Processing Record 3 of Set 7 | whitehorse
# Processing Record 4 of Set 7 | lagunas
# Processing Record 5 of Set 7 | linguere
# Processing Record 6 of Set 7 | pasni
# Processing Record 7 of Set 7 | clyde river
# Processing Record 8 of Set 7 | paragominas
# Processing Record 9 of Set 7 | ajdabiya
# Processing Record 10 of Set 7 | batsfjord
# Processing Record 11 of Set 7 | mecca
# Processing Record 12 of Set 7 | praia
# Processing Record 13 of Set 7 | kloulklubed
# Processing Record 14 of Set 7 | guanica
# Processing Record 15 of Set 7 | hobyo
# Processing Record 16 of Set 7 | sol-iletsk
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | lere
# Processing Record 19 of Set 7 | ketchikan
# Processing Record 20 of Set 7 | changping
# Processing Record 21 of Set 7 | kyzyl-suu
# Processing Record 22 of Set 7 | abha
# Processing Record 23 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 7 | port hawkesbury
# Processing Record 26 of Set 7 | coquimbo
# Processing Record 27 of Set 7 | itarema
# Processing Record 28 of Set 7 | kysyl-syr
# Processing Record 29 of Set 7 | vila velha
# Processing Record 30 of Set 7 | buncrana
# Processing Record 31 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 7 | oranjestad
# Processing Record 33 of Set 7 | pisco
# Processing Record 34 of Set 7 | santa maria
# Processing Record 35 of Set 7 | tieling
# Processing Record 36 of Set 7 | evensk
# Processing Record 37 of Set 7 | la romana
# Processing Record 38 of Set 7 | nuuk
# Processing Record 39 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 7 | sarangani
# Processing Record 41 of Set 7 | paamiut
# Processing Record 42 of Set 7 | kahului
# Processing Record 43 of Set 7 | kichera
# Processing Record 44 of Set 7 | itapirapua
# Processing Record 45 of Set 7 | lerwick
# Processing Record 46 of Set 7 | nambucca heads
# Processing Record 47 of Set 7 | miguel hidalgo
# Processing Record 48 of Set 7 | yulara
# Processing Record 49 of Set 7 | san policarpo
# Processing Record 50 of Set 7 | glenwood springs
# Processing Record 1 of Set 8 | kuvshinovo
# Processing Record 2 of Set 8 | oktyabrskoye
# Processing Record 3 of Set 8 | edd
# Processing Record 4 of Set 8 | ingleside
# Processing Record 5 of Set 8 | shumskiy
# Processing Record 6 of Set 8 | galich
# Processing Record 7 of Set 8 | sheltozero
# Processing Record 8 of Set 8 | santa vitoria do palmar
# Processing Record 9 of Set 8 | divnomorskoye
# Processing Record 10 of Set 8 | alboraya
# Processing Record 11 of Set 8 | marzuq
# Processing Record 12 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 8 | batagay-alyta
# Processing Record 14 of Set 8 | morden
# Processing Record 15 of Set 8 | namibe
# Processing Record 16 of Set 8 | vuktyl
# Processing Record 17 of Set 8 | roebourne
# Processing Record 18 of Set 8 | broome
# Processing Record 19 of Set 8 | pincher creek
# Processing Record 20 of Set 8 | kozhva
# Processing Record 21 of Set 8 | bom jardim
# Processing Record 22 of Set 8 | trairi
# Processing Record 23 of Set 8 | sept-iles
# Processing Record 24 of Set 8 | taoudenni
# Processing Record 25 of Set 8 | ryotsu
# Processing Record 26 of Set 8 | deep river
# Processing Record 27 of Set 8 | sola
# Processing Record 28 of Set 8 | vysokogornyy
# Processing Record 29 of Set 8 | norman wells
# Processing Record 30 of Set 8 | maceio
# Processing Record 31 of Set 8 | vieksniai
# Processing Record 32 of Set 8 | alofi
# Processing Record 33 of Set 8 | sao joao da barra
# Processing Record 34 of Set 8 | kapoeta
# Processing Record 35 of Set 8 | vao
# Processing Record 36 of Set 8 | zhifang
# Processing Record 37 of Set 8 | ulladulla
# Processing Record 38 of Set 8 | bangkalan
# Processing Record 39 of Set 8 | batagay
# Processing Record 40 of Set 8 | urucui
# Processing Record 41 of Set 8 | maromitsa
# Processing Record 42 of Set 8 | converse
# Processing Record 43 of Set 8 | saint-paul
# Processing Record 44 of Set 8 | marsh harbour
# Processing Record 45 of Set 8 | eureka
# Processing Record 46 of Set 8 | haines junction
# Processing Record 47 of Set 8 | puri
# Processing Record 48 of Set 8 | rancho grande
# Processing Record 49 of Set 8 | bonfim
# Processing Record 50 of Set 8 | quarai
# Processing Record 1 of Set 9 | adrar
# Processing Record 2 of Set 9 | san vicente de canete
# Processing Record 3 of Set 9 | sierra vista
# Processing Record 4 of Set 9 | moyale
# Processing Record 5 of Set 9 | henties bay
# Processing Record 6 of Set 9 | ahmadpur east
# Processing Record 7 of Set 9 | khandyga
# Processing Record 8 of Set 9 | kidal
# Processing Record 9 of Set 9 | salalah
# Processing Record 10 of Set 9 | lavrentiya
# Processing Record 11 of Set 9 | bathsheba
# Processing Record 12 of Set 9 | foz
# Processing Record 13 of Set 9 | valle de guadalupe
# Processing Record 14 of Set 9 | viedma
# Processing Record 15 of Set 9 | road town
# Processing Record 16 of Set 9 | lixourion
# Processing Record 17 of Set 9 | upata
# Processing Record 18 of Set 9 | port macquarie
# Processing Record 19 of Set 9 | half moon bay
# Processing Record 20 of Set 9 | sitka
# Processing Record 21 of Set 9 | cap malheureux
# Processing Record 22 of Set 9 | sevlievo
# Processing Record 23 of Set 9 | sabang
# Processing Record 24 of Set 9 | mareeba
# Processing Record 25 of Set 9 | straoane
# Processing Record 26 of Set 9 | gdov
# Processing Record 27 of Set 9 | camacha
# Processing Record 28 of Set 9 | auki
# Processing Record 29 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 9 | piney green
# Processing Record 31 of Set 9 | mahebourg
# Processing Record 32 of Set 9 | yeppoon
# Processing Record 33 of Set 9 | shitanjing
# Processing Record 34 of Set 9 | muros
# Processing Record 35 of Set 9 | walvis bay
# Processing Record 36 of Set 9 | buala
# Processing Record 37 of Set 9 | anori
# Processing Record 38 of Set 9 | bayan
# Processing Record 39 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 40 of Set 9 | yuksekova
# Processing Record 41 of Set 9 | la sarre
# Processing Record 42 of Set 9 | chimbote
# Processing Record 43 of Set 9 | kasongo-lunda
# Processing Record 44 of Set 9 | salinas
# Processing Record 45 of Set 9 | agutaya
# Processing Record 46 of Set 9 | longyearbyen
# Processing Record 47 of Set 9 | baripada
# Processing Record 48 of Set 9 | chinhoyi
# Processing Record 49 of Set 9 | los llanos de aridane
# Processing Record 50 of Set 9 | xining
# Processing Record 1 of Set 10 | toledo
# Processing Record 2 of Set 10 | abnub
# Processing Record 3 of Set 10 | dagua
# Processing Record 4 of Set 10 | saldanha
# Processing Record 5 of Set 10 | havre-saint-pierre
# Processing Record 6 of Set 10 | puerto madryn
# Processing Record 7 of Set 10 | nizwa
# Processing Record 8 of Set 10 | sinnamary
# Processing Record 9 of Set 10 | juliaca
# Processing Record 10 of Set 10 | ulagan
# Processing Record 11 of Set 10 | faya
# Processing Record 12 of Set 10 | xifeng
# Processing Record 13 of Set 10 | raudeberg
# Processing Record 14 of Set 10 | zaozerne
# Processing Record 15 of Set 10 | kavaratti
# Processing Record 16 of Set 10 | megion
# Processing Record 17 of Set 10 | naze
# Processing Record 18 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 10 | parksville
# Processing Record 20 of Set 10 | hay river
# Processing Record 21 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 22 of Set 10 | felipe carrillo puerto
# Processing Record 23 of Set 10 | west fargo
# Processing Record 24 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 10 | wicklow
# Processing Record 26 of Set 10 | ciechocinek
# Processing Record 27 of Set 10 | kabanjahe
# Processing Record 28 of Set 10 | devyatka
# City not found. Skipping...
# Processing Record 29 of Set 10 | waipawa
# Processing Record 30 of Set 10 | marinette
# Processing Record 31 of Set 10 | san cristobal
# Processing Record 32 of Set 10 | mandalgovi
# Processing Record 33 of Set 10 | manono
# Processing Record 34 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 10 | atar
# Processing Record 36 of Set 10 | coahuayana
# Processing Record 37 of Set 10 | andros town
# Processing Record 38 of Set 10 | huarmey
# Processing Record 39 of Set 10 | chumikan
# Processing Record 40 of Set 10 | homestead
# Processing Record 41 of Set 10 | la primavera
# Processing Record 42 of Set 10 | jinchang
# Processing Record 43 of Set 10 | cairns
# Processing Record 44 of Set 10 | ayabaca
# Processing Record 45 of Set 10 | kirakira
# Processing Record 46 of Set 10 | dandong
# Processing Record 47 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 48 of Set 10 | olga
# Processing Record 49 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 50 of Set 10 | chateauroux
# Processing Record 1 of Set 11 | ogulin
# Processing Record 2 of Set 11 | yablochnyy
# Processing Record 3 of Set 11 | jalu
# Processing Record 4 of Set 11 | clearwater
# Processing Record 5 of Set 11 | naples
# Processing Record 6 of Set 11 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 7 of Set 11 | ambunti
# Processing Record 8 of Set 11 | alvorada
# Processing Record 9 of Set 11 | smirnykh
# Processing Record 10 of Set 11 | kitimat
# Processing Record 11 of Set 11 | quibdo
# Processing Record 12 of Set 11 | hualmay
# Processing Record 13 of Set 11 | monywa
# Processing Record 14 of Set 11 | champerico
# Processing Record 15 of Set 11 | pacific grove
# Processing Record 16 of Set 11 | agno
# Processing Record 17 of Set 11 | bindura
# Processing Record 18 of Set 11 | tutoia
# Processing Record 19 of Set 11 | ancona
# Processing Record 20 of Set 11 | vila franca do campo
# Processing Record 21 of Set 11 | la ronge
# Processing Record 22 of Set 11 | peniche
# Processing Record 23 of Set 11 | binzhou
# Processing Record 24 of Set 11 | vestmannaeyjar
# Processing Record 25 of Set 11 | biak
# Processing Record 26 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 27 of Set 11 | bandarbeyla
# Processing Record 28 of Set 11 | harper
# Processing Record 29 of Set 11 | laguna
# Processing Record 30 of Set 11 | bengkulu
# Processing Record 31 of Set 11 | punta alta
# Processing Record 32 of Set 11 | berlevag
# Processing Record 33 of Set 11 | ambon
# Processing Record 34 of Set 11 | nikolayevsk-na-amure
# Processing Record 35 of Set 11 | akyab
# Processing Record 36 of Set 11 | juegang
# Processing Record 37 of Set 11 | stuttgart
# Processing Record 38 of Set 11 | karratha
# Processing Record 39 of Set 11 | morant bay
# Processing Record 40 of Set 11 | tabligbo
# Processing Record 41 of Set 11 | marathon
# Processing Record 42 of Set 11 | naantali
# Processing Record 43 of Set 11 | luwingu
# Processing Record 44 of Set 11 | severodvinsk
# Processing Record 45 of Set 11 | salta
# Processing Record 46 of Set 11 | ponta delgada
# Processing Record 47 of Set 11 | burns lake
# Processing Record 48 of Set 11 | makokou
# Processing Record 49 of Set 11 | kenora
# Processing Record 50 of Set 11 | lardos
# Processing Record 1 of Set 12 | katsuura
# Processing Record 2 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 12 | mattru
# Processing Record 4 of Set 12 | pitimbu
# Processing Record 5 of Set 12 | ginir
# Processing Record 6 of Set 12 | windhoek
# Processing Record 7 of Set 12 | pogar
# Processing Record 8 of Set 12 | navalmoral de la mata
# Processing Record 9 of Set 12 | dalbandin
# Processing Record 10 of Set 12 | kinablangan
# Processing Record 11 of Set 12 | misratah
# Processing Record 12 of Set 12 | richards bay
# Processing Record 13 of Set 12 | gremyachinsk
# Processing Record 14 of Set 12 | beringovskiy
# Processing Record 15 of Set 12 | goya
# Processing Record 16 of Set 12 | adoni
# Processing Record 17 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 18 of Set 12 | benjamin constant
# Processing Record 19 of Set 12 | valdivia
# Processing Record 20 of Set 12 | dwarka
# Processing Record 21 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 22 of Set 12 | zaozhuang
# Processing Record 23 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 12 | manama
# Processing Record 25 of Set 12 | zgorzelec
# Processing Record 26 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 12 | galveston
# Processing Record 28 of Set 12 | tamala
# Processing Record 29 of Set 12 | preobrazheniye
# Processing Record 30 of Set 12 | bundaberg
# Processing Record 31 of Set 12 | pangai
# Processing Record 32 of Set 12 | saint-augustin
# Processing Record 33 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 34 of Set 12 | eufaula
# Processing Record 35 of Set 12 | morki
# Processing Record 36 of Set 12 | rajapur
# Processing Record 37 of Set 12 | ahipara
# Processing Record 38 of Set 12 | pontianak
# Processing Record 39 of Set 12 | pailon
# Processing Record 40 of Set 12 | puma
# Processing Record 41 of Set 12 | almenara
# Processing Record 42 of Set 12 | kartaly
# Processing Record 43 of Set 12 | pangkalanbuun
# Processing Record 44 of Set 12 | plast
# Processing Record 45 of Set 12 | porto santo
# Processing Record 46 of Set 12 | vagur
# Processing Record 47 of Set 12 | shingu
# Processing Record 48 of Set 12 | rock springs
# Processing Record 49 of Set 12 | vanimo
# Processing Record 50 of Set 12 | brainerd
# Processing Record 1 of Set 13 | clinton
# Processing Record 2 of Set 13 | inta
# Processing Record 3 of Set 13 | nova friburgo
# Processing Record 4 of Set 13 | khakhea
# Processing Record 5 of Set 13 | cockburn town
# Processing Record 6 of Set 13 | rundu
# Processing Record 7 of Set 13 | labuhan
# Processing Record 8 of Set 13 | tecoanapa
# Processing Record 9 of Set 13 | napasar
# Processing Record 10 of Set 13 | hit
# Processing Record 11 of Set 13 | entre rios
# Processing Record 12 of Set 13 | inuvik
# Processing Record 13 of Set 13 | dunyapur
# Processing Record 14 of Set 13 | fairbanks
# Processing Record 15 of Set 13 | altay
# Processing Record 16 of Set 13 | tari
# Processing Record 17 of Set 13 | gelgaudiskis
# Processing Record 18 of Set 13 | shache
# Processing Record 19 of Set 13 | muzhi
# Processing Record 20 of Set 13 | khromtau
# Processing Record 21 of Set 13 | toora-khem
# Processing Record 22 of Set 13 | ust-kan
# Processing Record 23 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 13 | goure
# Processing Record 25 of Set 13 | tokonou
# Processing Record 26 of Set 13 | novyy urengoy
# Processing Record 27 of Set 13 | asosa
# Processing Record 28 of Set 13 | seoul
# Processing Record 29 of Set 13 | ostrovnoy
# Processing Record 30 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 13 | kodiak
# Processing Record 32 of Set 13 | ternate
# Processing Record 33 of Set 13 | zaysan
# Processing Record 34 of Set 13 | manturovo
# Processing Record 35 of Set 13 | teul
# City not found. Skipping...
# Processing Record 36 of Set 13 | vredendal
# Processing Record 37 of Set 13 | skotterud
# Processing Record 38 of Set 13 | yerbogachen
# Processing Record 39 of Set 13 | sao felix do xingu
# Processing Record 40 of Set 13 | nisia floresta
# Processing Record 41 of Set 13 | kokoda
# Processing Record 42 of Set 13 | general roca
# Processing Record 43 of Set 13 | warmbad
# Processing Record 44 of Set 13 | nishihara
# Processing Record 45 of Set 13 | lodja
# Processing Record 46 of Set 13 | ola
# Processing Record 47 of Set 13 | waverly
# Processing Record 48 of Set 13 | tabou
# Processing Record 49 of Set 13 | baoqing
# Processing Record 50 of Set 13 | mokhsogollokh
# Processing Record 1 of Set 14 | lakhdenpokhya
# Processing Record 2 of Set 14 | scottsbluff
# Processing Record 3 of Set 14 | panzhihua
# Processing Record 4 of Set 14 | fershampenuaz
# Processing Record 5 of Set 14 | dubbo
# Processing Record 6 of Set 14 | kalush
# Processing Record 7 of Set 14 | tabuk
# Processing Record 8 of Set 14 | washougal
# Processing Record 9 of Set 14 | wynyard
# Processing Record 10 of Set 14 | watertown
# Processing Record 11 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 14 | izhma
# Processing Record 13 of Set 14 | lethem
# Processing Record 14 of Set 14 | bhatkal
# Processing Record 15 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 16 of Set 14 | wazzan
# City not found. Skipping...
# Processing Record 17 of Set 14 | inhambane
# Processing Record 18 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 19 of Set 14 | russell
# Processing Record 20 of Set 14 | nyurba
# Processing Record 21 of Set 14 | sechura
# Processing Record 22 of Set 14 | siddipet
# Processing Record 23 of Set 14 | havoysund
# Processing Record 24 of Set 14 | pimenta bueno
# Processing Record 25 of Set 14 | constitucion
# Processing Record 26 of Set 14 | manicore
# Processing Record 27 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 14 | bandundu
# Processing Record 29 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 31 of Set 14 | pyaozerskiy
# Processing Record 32 of Set 14 | salinopolis
# Processing Record 33 of Set 14 | khuzdar
# Processing Record 34 of Set 14 | hvide sande
# Processing Record 35 of Set 14 | ploemeur
# Processing Record 36 of Set 14 | kismayo
# Processing Record 37 of Set 14 | lucapa
# Processing Record 38 of Set 14 | maryborough
# Processing Record 39 of Set 14 | mahibadhoo
# Processing Record 40 of Set 14 | shaunavon
# Processing Record 41 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 14 | marawi
# Processing Record 43 of Set 14 | saint-louis
# Processing Record 44 of Set 14 | loandjili
# Processing Record 45 of Set 14 | nalut
# Processing Record 46 of Set 14 | taybad
# Processing Record 47 of Set 14 | el alto
# Processing Record 48 of Set 14 | mandali
# Processing Record 49 of Set 14 | ghimbav
# Processing Record 50 of Set 14 | gwanda
# Processing Record 1 of Set 15 | andenes
# Processing Record 2 of Set 15 | cuenca
# Processing Record 3 of Set 15 | yar-sale
# Processing Record 4 of Set 15 | lyaskelya
# Processing Record 5 of Set 15 | svecha
# Processing Record 6 of Set 15 | ramygala
# Processing Record 7 of Set 15 | acarau
# Processing Record 8 of Set 15 | benjamin hill
# Processing Record 9 of Set 15 | kudahuvadhoo
# Processing Record 10 of Set 15 | kalabo
# Processing Record 11 of Set 15 | port pirie
# Processing Record 12 of Set 15 | asau
# Processing Record 13 of Set 15 | beterou
# Processing Record 14 of Set 15 | pacifica
# Processing Record 15 of Set 15 | margate
# Processing Record 16 of Set 15 | mpulungu
# Processing Record 17 of Set 15 | maningrida
# Processing Record 18 of Set 15 | kaeo
# Processing Record 19 of Set 15 | banda aceh
# Processing Record 20 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 15 | nelson bay
# Processing Record 22 of Set 15 | olafsvik
# Processing Record 23 of Set 15 | kasempa
# Processing Record 24 of Set 15 | bagotville
# Processing Record 25 of Set 15 | severomuysk
# Processing Record 26 of Set 15 | sansai
# City not found. Skipping...
# Processing Record 27 of Set 15 | makakilo city
# Processing Record 28 of Set 15 | khani
# Processing Record 29 of Set 15 | osa
# Processing Record 30 of Set 15 | shelburne
# Processing Record 31 of Set 15 | san quintin
# Processing Record 32 of Set 15 | harer
# Processing Record 33 of Set 15 | mana
# Processing Record 34 of Set 15 | ilhabela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq  77.4840  -69.3632     -0.54        98          98
# 1    Chokurdakh  70.6333  147.9167    -31.68        99         100
# 2    Alamogordo  32.8995 -105.9603     52.61        34           1
# 3  Punta Arenas -53.1500  -70.9167     53.71        54          90
# 4    Hambantota   6.1241   81.1185     75.54       100          75
# 5     Egvekinot  66.3167 -179.1667    -16.08        84           0
# 6          Hilo  19.7297 -155.0900     78.53        65          40
# 7     Saskylakh  71.9167  114.0833     -3.87        93          98
# 8    Storm Lake  42.6411  -95.2097     39.42        75           1
# 9   Tuktoyaktuk  69.4541 -133.0374     -6.09        96         100
#
#    Wind Speed Country                 Date Current Description
# 0        1.90      GL  2021-11-28 01:07:58     overcast clouds
# 1        0.58      RU  2021-11-28 01:07:58     overcast clouds
# 2        8.05      US  2021-11-28 01:05:57           clear sky
# 3       11.50      CL  2021-11-28 01:07:59     overcast clouds
# 4        5.75      LK  2021-11-28 01:07:59       broken clouds
# 5        4.97      RU  2021-11-28 01:08:00           clear sky
# 6        6.91      US  2021-11-28 01:08:00    scattered clouds
# 7       10.27      RU  2021-11-28 01:08:00     overcast clouds
# 8       11.50      US  2021-11-28 01:08:01           clear sky
# 9       16.82      CA  2021-11-28 01:04:10          light snow

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       Qaanaaq      GL  2021-11-28 01:07:58  77.4840  -69.3632     -0.54
# 1    Chokurdakh      RU  2021-11-28 01:07:58  70.6333  147.9167    -31.68
# 2    Alamogordo      US  2021-11-28 01:05:57  32.8995 -105.9603     52.61
# 3  Punta Arenas      CL  2021-11-28 01:07:59 -53.1500  -70.9167     53.71
# 4    Hambantota      LK  2021-11-28 01:07:59   6.1241   81.1185     75.54
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        98          98        1.90     overcast clouds
# 1        99         100        0.58     overcast clouds
# 2        34           1        8.05           clear sky
# 3        54          90       11.50     overcast clouds
# 4       100          75        5.75       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
